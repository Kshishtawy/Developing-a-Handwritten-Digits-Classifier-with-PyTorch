# %% [markdown]
# # Introduction
#
# In this project, you will build a neural network of your own design to evaluate the MNIST dataset.
#
# Some of the benchmark results on MNIST include can be found [on Yann LeCun's page](http://yann.lecun.com/exdb/mnist/) and include:
#
# 88% [Lecun et al., 1998](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf)
# 95.3% [Lecun et al., 1998](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf)
# 99.65% [Ciresan et al., 2011](http://people.idsia.ch/~juergen/ijcai2011.pdf)
#
# MNIST is a great dataset for sanity checking your models, since the accuracy levels achieved by large convolutional neural networks and small linear models are both quite high. This makes it important to be familiar with the data.
#
# ## Imports

# %%
## This cell contains the essential imports you will need – DO NOT CHANGE THE CONTENTS! ##
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Load the Dataset
#
# Specify your transforms as a list if you intend to .
# The transforms module is already loaded as `transforms`.
#
# MNIST is fortunately included in the torchvision module.
# Then, you can create your dataset using the `MNIST` object from `torchvision.datasets` ([the documentation is available here](https://pytorch.org/vision/stable/datasets.html#mnist)).
# Make sure to specify `download=True`!
#
# Once your dataset is created, you'll also need to define a `DataLoader` from the `torch.utils.data` module for both the train and the test set.

# %%
# Define transforms
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# Create training set and define training dataloader
training_data = torchvision.datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_test = torchvision.datasets.MNIST(root='data', train=False, download=True, transform=transform)

# Create test set and define test dataloader
train_loader = DataLoader(training_data, batch_size=128, shuffle=True)
test_loader = DataLoader(test_test, batch_size=128)

# %% [markdown]
# ## Justify your preprocessing
#
# In your own words, why did you choose the transforms you chose? If you didn't use any preprocessing steps, why not?

# %% [markdown]
# **The only preprocessing made was "Normlization" to convert the grayscale values to tensors with numbers between 0 and 1. The image size in this dataset seems perfect - 28*28 - and we will not need to rotate images or flip them since we will predict images which are always in the right rotations (for example, number four flipped is not actually four)**

# %% [markdown]
# ## Explore the Dataset
# Using matplotlib, numpy, and torch, explore the dimensions of your data.
#
# You can view images using the `show5` function defined below – it takes a data loader as an argument.
# Remember that normalized images will look really weird to you! You may want to try changing your transforms to view images.
# Typically using no transforms other than `toTensor()` works well for viewing – but not as well for training your network.
# If `show5` doesn't work, go back and check your code for creating your data loaders and your training/test sets.

# %%
## This cell contains a function for showing 5 images from a dataloader – DO NOT CHANGE THE CONTENTS! ##
def show5(img_loader):
    dataiter = iter(img_loader)
    
    batch = next(dataiter)
    labels = batch[1][0:5]
    images = batch[0][0:5]
    for i in range(5):
        print(int(labels[i].detach()))
    
        image = images[i].numpy()
        plt.imshow(image.T.squeeze().T)
        plt.show()

# %%
# Explore data
show5(train_loader)
# Out:
# 8
# 9
# 4
# 5
# 3

# %% [markdown]
# ## Build your Neural Network
# Using the layers in `torch.nn` (which has been imported as `nn`) and the `torch.nn.functional` module (imported as `F`), construct a neural network based on the parameters of the dataset.
# Use any architecture you like.
#
# *Note*: If you did not flatten your tensors in your transforms or as part of your preprocessing and you are using only `Linear` layers, make sure to use the `Flatten` layer in your network!

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.activation = F.relu
        self.layer1 = nn.Linear(28 * 28 * 1, 128)
        self.layer2 = nn.Linear(128, 64)
        self.layer3 = nn.Linear(64, 10)
        
    def forward(self, x):
        x = torch.flatten(x, 1)
        x = self.activation(self.layer1(x))
        x = self.activation(self.layer2(x))
        x = self.layer3(x)
        x = F.softmax(x, dim=1)
        return x

# %% [markdown]
# Specify a loss function and an optimizer, and instantiate the model.
#
# If you use a less common loss function, please note why you chose that loss function in a comment.

# %%
net = Net()

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Running your Neural Network
# Use whatever method you like to train your neural network, and ensure you record the average loss at each epoch.
# Don't forget to use `torch.device()` and the `.to()` method for both your model and your data if you are using GPU!
#
# If you want to print your loss **during** each epoch, you can use the `enumerate` function and print the loss after a set number of batches. 250 batches works well for most people!

# %%
# Move the model to the GPU if CUDA is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
# Out:
# Net(
#   (layer1): Linear(in_features=784, out_features=128, bias=True)
#   (layer2): Linear(in_features=128, out_features=64, bias=True)
#   (layer3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
len(train_loader.dataset)
# Out:
# 60000

# %%
# number of epochs
num_epochs = 10

# creating lists for loss history
train_loss_history = list()
val_loss_history = list()

# The start of the training
for epoch in range(num_epochs):
    # putting the model in training mode
    net.train()
    # setting the epoch loss and number of correct predictions to zero
    train_loss = 0.0
    train_correct = 0
    
    for i, data in enumerate(train_loader):
        inputs, labels = data
        
        if torch.cuda.is_available():
            inputs, labels = inputs.to(device), labels.to(device)
    
        optimizer.zero_grad()
    
        outputs = net(inputs)
    
        loss = criterion(outputs, labels)
    
        loss.backward()
    
        optimizer.step()
    
        _, preds = torch.max(outputs.data, 1)
        train_correct += (preds == labels).sum().item()
        train_loss += loss.item()
        
    print(f"Epoch {epoch + 1} training accuracy: {train_correct/len(train_loader.dataset) * 100:.2f}% training loss: {train_loss/len(train_loader):.5f}")
    train_loss_history.append(train_loss/len(train_loader))
    
    # The validation phase
    val_loss = 0.0
    val_correct = 0
    net.eval()
    for inputs, labels in test_loader:
        if torch.cuda.is_available():
            inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        
        _, preds = torch.max(outputs.data, 1)
        val_correct += (preds == labels).sum().item()
        val_loss += loss.item()
    print(f"Epoch {epoch + 1} validation accuracy: {val_correct/len(test_loader.dataset) * 100:.2f}% validation loss: {val_loss/len(test_loader):.5f}")
    val_loss_history.append(val_loss/len(test_loader))
# Out:
# Epoch 1 training accuracy: 57.49% training loss: 1.63772
# Epoch 1 validation accuracy: 81.76% validation loss: 0.77168
# Epoch 2 training accuracy: 84.91% training loss: 0.57357
# Epoch 2 validation accuracy: 87.88% validation loss: 0.43621
# Epoch 3 training accuracy: 88.50% training loss: 0.41259
# Epoch 3 validation accuracy: 89.78% validation loss: 0.35924
# Epoch 4 training accuracy: 89.80% training loss: 0.35995
# Epoch 4 validation accuracy: 90.70% validation loss: 0.32538
# Epoch 5 training accuracy: 90.58% training loss: 0.33038
# Epoch 5 validation accuracy: 91.33% validation loss: 0.30391
# Epoch 6 training accuracy: 91.11% training loss: 0.30943
# Epoch 6 validation accuracy: 91.58% validation loss: 0.29073
# Epoch 7 training accuracy: 91.44% training loss: 0.29430
# Epoch 7 validation accuracy: 92.04% validation loss: 0.27914
# Epoch 8 training accuracy: 91.85% training loss: 0.28096
# Epoch 8 validation accuracy: 92.36% validation loss: 0.26521
# Epoch 9 training accuracy: 92.25% training loss: 0.26894
# Epoch 9 validation accuracy: 92.65% validation loss: 0.25649
# Epoch 10 training accuracy: 92.55% training loss: 0.25821
# Epoch 10 validation accuracy: 92.57% validation loss: 0.24930

# %% [markdown]
# Plot the training loss (and validation loss/accuracy, if recorded).

# %%
plt.plot(train_loss_history, label="Training Loss")
plt.plot(val_loss_history, label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Testing your model
# Using the previously created `DataLoader` for the test set, compute the percentage of correct predictions using the highest probability prediction.
#
# If your accuracy is over 90%, great work, but see if you can push a bit further!
# If your accuracy is under 90%, you'll need to make improvements.
# Go back and check your model architecture, loss function, and optimizer to make sure they're appropriate for an image classification task.

# %%
correct_predictions = 0
total_predictions = 0

for inputs, labels in test_loader:
    if torch.cuda.is_available():
        inputs, labels = inputs.to(device), labels.to(device)
        
    outputs = net(inputs)
    _, preds = torch.max(outputs.data, 1)
    total_predictions += labels.size(0)
    correct_predictions += (preds == labels).sum().item()
    accuracy = (correct_predictions / total_predictions) * 100
    
print(f"Accuracy: {accuracy}%")
# Out:
# Accuracy: 92.57%

# %% [markdown]
# ## Improving your model
#
# Once your model is done training, try tweaking your hyperparameters and training again below to improve your accuracy on the test set!

# %%
# exprimenting with the optimizer

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.99, weight_decay= 0.001)

# %%
# number of epochs
num_epochs = 20

# creating lists for loss history
train_loss_history = list()
val_loss_history = list()

# The start of the training
for epoch in range(num_epochs):
    # putting the model in training mode
    net.train()
    # setting the epoch loss and number of correct predictions to zero
    train_loss = 0.0
    train_correct = 0
    
    for i, data in enumerate(train_loader):
        inputs, labels = data
        
        if torch.cuda.is_available():
            inputs, labels = inputs.to(device), labels.to(device)
    
        optimizer.zero_grad()
    
        outputs = net(inputs)
    
        loss = criterion(outputs, labels)
    
        loss.backward()
    
        optimizer.step()
    
        _, preds = torch.max(outputs.data, 1)
        train_correct += (preds == labels).sum().item()
        train_loss += loss.item()
        
    print(f"Epoch {epoch + 1} training accuracy: {train_correct/len(train_loader.dataset) * 100:.2f}% training loss: {train_loss/len(train_loader):.5f}")
    train_loss_history.append(train_loss/len(train_loader))
    
    # The validation phase
    val_loss = 0.0
    val_correct = 0
    net.eval()
    for inputs, labels in test_loader:
        if torch.cuda.is_available():
            inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        
        _, preds = torch.max(outputs.data, 1)
        val_correct += (preds == labels).sum().item()
        val_loss += loss.item()
    print(f"Epoch {epoch + 1} validation accuracy: {val_correct/len(test_loader.dataset) * 100:.2f}% validation loss: {val_loss/len(test_loader):.5f}")
    val_loss_history.append(val_loss/len(test_loader))
# Out:
# Epoch 1 training accuracy: 92.14% training loss: 0.26705
# Epoch 1 validation accuracy: 92.98% validation loss: 0.23375
# Epoch 2 training accuracy: 93.84% training loss: 0.20436
# Epoch 2 validation accuracy: 94.57% validation loss: 0.18185
# Epoch 3 training accuracy: 95.20% training loss: 0.15984
# Epoch 3 validation accuracy: 95.63% validation loss: 0.14081
# Epoch 4 training accuracy: 96.25% training loss: 0.12477
# Epoch 4 validation accuracy: 95.93% validation loss: 0.12524
# Epoch 5 training accuracy: 96.69% training loss: 0.11035
# Epoch 5 validation accuracy: 96.63% validation loss: 0.10971
# Epoch 6 training accuracy: 97.05% training loss: 0.09620
# Epoch 6 validation accuracy: 97.03% validation loss: 0.09737
# Epoch 7 training accuracy: 97.42% training loss: 0.08672
# Epoch 7 validation accuracy: 96.75% validation loss: 0.10162
# Epoch 8 training accuracy: 97.57% training loss: 0.08144
# Epoch 8 validation accuracy: 96.83% validation loss: 0.09681
# Epoch 9 training accuracy: 97.96% training loss: 0.06872
# Epoch 9 validation accuracy: 97.20% validation loss: 0.08772
# Epoch 10 training accuracy: 98.02% training loss: 0.06655
# Epoch 10 validation accuracy: 97.21% validation loss: 0.09078
# Epoch 11 training accuracy: 98.15% training loss: 0.06332
# Epoch 11 validation accuracy: 97.29% validation loss: 0.08309
# Epoch 12 training accuracy: 98.33% training loss: 0.05783
# Epoch 12 validation accuracy: 97.67% validation loss: 0.07730
# Epoch 13 training accuracy: 98.46% training loss: 0.05265
# Epoch 13 validation accuracy: 97.42% validation loss: 0.07934
# Epoch 14 training accuracy: 98.46% training loss: 0.05320
# Epoch 14 validation accuracy: 97.58% validation loss: 0.07850
# Epoch 15 training accuracy: 98.40% training loss: 0.05350
# Epoch 15 validation accuracy: 97.55% validation loss: 0.07687
# Epoch 16 training accuracy: 98.49% training loss: 0.05016
# Epoch 16 validation accuracy: 97.79% validation loss: 0.06916
# Epoch 17 training accuracy: 98.72% training loss: 0.04373
# Epoch 17 validation accuracy: 97.56% validation loss: 0.07512
# Epoch 18 training accuracy: 98.54% training loss: 0.04871
# Epoch 18 validation accuracy: 97.30% validation loss: 0.08044
# Epoch 19 training accuracy: 98.77% training loss: 0.04312
# Epoch 19 validation accuracy: 97.62% validation loss: 0.07828
# Epoch 20 training accuracy: 98.66% training loss: 0.04522
# Epoch 20 validation accuracy: 97.66% validation loss: 0.07798

# %% [markdown]
# ## Final accuracy after tweaking the model

# %%
correct_predictions = 0
total_predictions = 0

for inputs, labels in test_loader:
    if torch.cuda.is_available():
        inputs, labels = inputs.to(device), labels.to(device)
        
    outputs = net(inputs)
    _, preds = torch.max(outputs.data, 1)
    total_predictions += labels.size(0)
    correct_predictions += (preds == labels).sum().item()
    accuracy = (correct_predictions / total_predictions) * 100
    
print(f"Accuracy: {accuracy}%")
# Out:
# Accuracy: 97.66%

# %% [markdown]
# ## Saving your model
# Using `torch.save`, save your model for future loading.

# %%
torch.save(net.state_dict(), "saved_model.pth")
